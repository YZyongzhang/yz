# %%
import urllib.request as url
request = url.Request(url='https://jwxt.bistu.edu.cn/jwapp/sys/wdkb/*default/index.do?EMAP_LANG=zh#/xskcb')
schedule_html = url.urlopen(request).read().decode('utf-8')
print(schedule_html)

# %%
cookie_value = 'EMAP_LANG:zh;GS_SESSIONID:1e07e3a645ceaf1b6426a399594d711f;Hm_lvt_c261c1043dc7de23df8add1cc5c9852f:1740321049,1740726004,1742382196;JSESSIONID:'
